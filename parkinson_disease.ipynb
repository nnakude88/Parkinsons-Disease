# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
pd = pd.read_csv("parkinsons_disease_data.csv")
pd
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          3058   85       0          3               1  19.619878        0
# 1          3059   75       0          0               2  16.247339        1
# 2          3060   70       1          0               0  15.368239        0
# 3          3061   52       0          0               0  15.454557        0
# 4          3062   87       0          0               1  18.616042        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2100       5158   87       1          0               2  38.483841        0
# 2101       5159   67       0          0               1  33.694396        1
# 2102       5160   65       0          0               2  22.829631        0
# 2103       5161   61       1          0               0  16.871030        1
# 2104       5162   56       0          0               2  16.569934        0
#
# ...

# %%
pd.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryParkinsons', 'TraumaticBrainInjury',
#        'Hypertension', 'Diabetes', 'Depression', 'Stroke', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'UPDRS', 'MoCA', 'FunctionalAssessment',
#        'Tremor', 'Rigidity', 'Bradykinesia', 'PosturalInstability',
#        'SpeechProblems', 'SleepDisorders', 'Constipation', 'Diagnosis',
#        'DoctorInCharge'],
#       dtype='object')

# %%
pd.shape
# Out:
# (2105, 35)

# %%
# Display the first few rows
pd.head()

# Get dataset information (columns, data types, non-null values)
pd.info()

# Descriptive statistics
pd.describe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105 entries, 0 to 2104
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   PatientID                 2105 non-null   int64
#  1   Age                       2105 non-null   int64
#  2   Gender                    2105 non-null   int64
#  3   Ethnicity                 2105 non-null   int64
#  4   EducationLevel            2105 non-null   int64
#  5   BMI                       2105 non-null   float64
#  6   Smoking                   2105 non-null   int64
#  7   AlcoholConsumption        2105 non-null   float64
#  8   PhysicalActivity          2105 non-null   float64
#  9   DietQuality               2105 non-null   float64
#  10  SleepQuality              2105 non-null   float64
#  11  FamilyHistoryParkinsons   2105 non-null   int64
#  12  TraumaticBrainInjury      2105 non-null   int64
# ...

# %%
pd.dtypes
# Out:
# PatientID                     int64
# Age                           int64
# Gender                        int64
# Ethnicity                     int64
# EducationLevel                int64
# BMI                         float64
# Smoking                       int64
# AlcoholConsumption          float64
# PhysicalActivity            float64
# DietQuality                 float64
# SleepQuality                float64
# FamilyHistoryParkinsons       int64
# TraumaticBrainInjury          int64
# Hypertension                  int64
# Diabetes                      int64
# Depression                    int64
# Stroke                        int64
# SystolicBP                    int64
# DiastolicBP                   int64
# CholesterolTotal            float64
# CholesterolLDL              float64
# CholesterolHDL              float64
# CholesterolTriglycerides    float64
# UPDRS                       float64
# MoCA                        float64
# FunctionalAssessment        float64
# ...

# %%
# Check for missing values
pd.isnull().sum()
# Out:
# PatientID                   0
# Age                         0
# Gender                      0
# Ethnicity                   0
# EducationLevel              0
# BMI                         0
# Smoking                     0
# AlcoholConsumption          0
# PhysicalActivity            0
# DietQuality                 0
# SleepQuality                0
# FamilyHistoryParkinsons     0
# TraumaticBrainInjury        0
# Hypertension                0
# Diabetes                    0
# Depression                  0
# Stroke                      0
# SystolicBP                  0
# DiastolicBP                 0
# CholesterolTotal            0
# CholesterolLDL              0
# CholesterolHDL              0
# CholesterolTriglycerides    0
# UPDRS                       0
# MoCA                        0
# FunctionalAssessment        0
# Tremor                      0
# Rigidity                    0
# Bradykinesia                0
# PosturalInstability         0
# SpeechProblems              0
# ...

# %% [markdown]
# ## VISUALIZATION.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(pd['Age'], kde=True, color='blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=pd, x='Gender', palette='coolwarm')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\97323020.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pd, x='Gender', palette='coolwarm')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=pd, x='Ethnicity', palette='Set2')
plt.title('Ethnicity Distribution')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\210944770.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pd, x='Ethnicity', palette='Set2')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=pd, x='EducationLevel', palette='Set1')
plt.title('Education Level Distribution')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\4028881619.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pd, x='EducationLevel', palette='Set1')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(pd['BMI'], kde=True, color='purple')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=pd, x='Smoking', palette='husl')
plt.title('Smoking Habits')
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\2966754010.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pd, x='Smoking', palette='husl')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(pd['SystolicBP'], kde=True, color='green')
plt.title('Systolic Blood Pressure Distribution')
plt.xlabel('SystolicBP')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=pd, x='Hypertension', palette='dark')
plt.title('Hypertension Prevalence')
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\1993539277.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pd, x='Hypertension', palette='dark')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=pd, x='Gender', hue='Diagnosis', palette='Set2')
plt.title('Gender vs. Diagnosis')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=pd, x='EducationLevel', y='MoCA', palette='husl')
plt.title('Education Level vs. MoCA Scores')
plt.xlabel('Education Level')
plt.ylabel('MoCA Score')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\1485845501.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=pd, x='EducationLevel', y='MoCA', palette='husl')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=pd, x='Hypertension', y='SystolicBP', palette='Set3')
plt.title('Hypertension vs. Systolic Blood Pressure')
plt.xlabel('Hypertension')
plt.ylabel('Systolic BP')
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\1251743602.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=pd, x='Hypertension', y='SystolicBP', palette='Set3')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=pd, x='Tremor', y='MoCA', palette='Paired')
plt.title('Tremor Severity vs. MoCA Scores')
plt.xlabel('Tremor')
plt.ylabel('MoCA Score')
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_8944\2004311410.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=pd, x='Tremor', y='MoCA', palette='Paired')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=pd, x='FamilyHistoryParkinsons', hue='Diagnosis', palette='Set2')
plt.title('Family History of Parkinsons vs. Diagnosis')
plt.xlabel('Family History of Parkinsons')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=pd, x='Ethnicity', hue='Smoking', palette='Set2')
plt.title('Smoking by Ethnicity')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Smoking')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=pd, x='Smoking', hue='Gender', palette='Set1')
plt.title('Smoking Habits by Gender')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=pd, x='EducationLevel', hue='Smoking', palette='Set2')
plt.title('Smoking Habits by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Smoking')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=pd, x='Smoking', y='Age', hue='SleepDisorders', palette='Set2')
plt.title('Age Distribution by Smoking Status and Sleep Disorders')
plt.xlabel('Smoking Status')
plt.ylabel('Age')
plt.legend(title='Sleep Disorders')
plt.show()
